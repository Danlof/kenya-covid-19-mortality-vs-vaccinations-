# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
import numpy as np
import datetime
import seaborn as sns

# %%
#load the data
my_filepath=open("H:\datascience\seaborn_vis\covid-vaccination-vs-death_ratio.csv")
my_data=pd.read_csv(my_filepath, index_col="date",parse_dates=True )

# %%
my_data.head()
# Out:
#             Unnamed: 0      country iso_code  total_vaccinations  \
# date
# 2021-11-05           0  Afghanistan      AFG              504502
# 2021-05-20           1  Afghanistan      AFG              547901
# 2021-05-24           2  Afghanistan      AFG              573277
# 2021-05-26           3  Afghanistan      AFG              590454
# 2021-05-27           4  Afghanistan      AFG              593313
#
#             people_vaccinated  people_fully_vaccinated  New_deaths            \
# date
# 2021-11-05             448878                    55624          12  40374668
# 2021-05-20             470341                    77560          10  40374668
# 2021-05-24             476367                    96910          10  40374668
# 2021-05-26             479372                   111082          19  40374668
# 2021-05-27             479574                   113739          14  40374668
#
#                ratio
# date
# 2021-11-05  1.111781
# 2021-05-20  1.164941
# 2021-05-24  1.179866
# ...

# %%
subset=my_data.sample(n=200)
subset
# Out:
#             Unnamed: 0         country iso_code  total_vaccinations  \
# date
# 2021-04-27       11801       Greenland      GRL               13214
# 2021-04-05        2069         Bahrain      BHR             1301773
# 2021-09-28       24223          Poland      POL            37186150
# 2021-07-04        5753  Cayman Islands      CYM               53474
# 2021-10-06       21231         Morocco      MAR            16237673
# ...                ...             ...      ...                 ...
# 2021-09-05       29437        Thailand      THA             1809894
# 2021-08-07        1005           Aruba      ABW              130121
# 2021-08-17       23040        Pakistan      PAK            44322217
# 2022-03-23        9200     El Salvador      SLV            10371554
# 2021-10-19       24234          Poland      POL            38373412
#
#             people_vaccinated  people_fully_vaccinated  New_deaths             \
# date
# ...

# %%
#to see all the possible countries in the dataset
my_data["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cabo Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Cook Islands', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cura̤ao', 'Cyprus', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Estonia', 'Ethiopia',
#        'Falkland Islands (Malvinas)', 'Fiji', 'Finland', 'France',
# ...

# %%
#to find the number of the countries the dataset
my_data["country"].nunique()
# Out:
# 197

# %%
#plotting the data

plt.figure(figsize=(14,6))
plt.title("A line plot showing the % of vaccinations in every country per day and the deaths per day")
sns.lineplot(data=my_data['people_vaccinated'],label="number of vaccinatedd people per day")
# Out:
# <AxesSubplot:title={'center':'A line plot showing the % of vaccinations in every country per day and the deaths per day'}, xlabel='date', ylabel='people_vaccinated'>

# %%
#filtering the data to use only data from kenya , sweden, saudi arabia and italy
my_data2=my_data[my_data["country"].isin(['Kenya','Sweden','Saudi Arabia','Italy'])]
print(my_data2)
# Out:
#             Unnamed: 0 country iso_code  total_vaccinations  \
# date
# 2021-04-01       14817   Italy      ITA              196638
# 2021-05-01       14818   Italy      ITA              276896
# 2021-06-01       14819   Italy      ITA              342075
# 2021-07-01       14820   Italy      ITA              434720
# 2021-08-01       14821   Italy      ITA              531704
# ...                ...     ...      ...                 ...
# 2022-03-18       28854  Sweden      SWE            20909304
# 2022-03-22       28855  Sweden      SWE            20981011
# 2022-03-23       28856  Sweden      SWE            21000229
# 2022-03-24       28857  Sweden      SWE            21026443
# 2022-03-25       28858  Sweden      SWE            21053545
#
#             people_vaccinated  people_fully_vaccinated  New_deaths            \
# date
# 2021-04-01             196638                        9         347  60320493
# ...

# %%
#plot the data 

my_data3=my_data[my_data["country"].isin(["Kenya"])]

#picking columns of date, total vaccinated people and deaths per day 
data_col1=my_data3.filter(['date','people_fully_vaccinated','New_deaths'])

#plotting the above data in lineplot 
plt.figure(figsize=(14,6))
sns.lineplot(data=data_col)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plt.figure(figsize=(14,6))
plt.title("line plot for new deaths per day")
sns.lineplot(data=my_data3['New_deaths'])
# Out:
# <AxesSubplot:title={'center':'line plot for new deaths per day'}, xlabel='date', ylabel='New_deaths'>
